# %% [markdown]
# # Chapter 2
# ## Open exercises

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### Task 5
#
# Draw the lines
#
# y = 2x + 1,
# y = 2x + 2,
# y = 2x + 3
# in the same figure.
#
# Use different drawing colors and line types for your graphs to make them stand out in black and white. Set the image title and captions for the horizontal and vertical axes.

# %%
x = np.linspace(-5,5,40)
y1 = 2*x+1
y2 = 2*x+2
y3 = 2*x+3

plt.plot(x,y1,".",x,y2,"-.",x,y3,"*")
plt.title("Task 5: Drawing lines")
plt.ylabel("y")
plt.xlabel("x")
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# ### Task 6
#
# Create a numpy table x that contains the values ​​1,2,3,4,5,6,7,8,9.
#
# Create another table y with the values ​​-0.57, -2.57, -4.80, -7.36, -8.78, -10.52, -12.85, -14.69, -16.78.
#
# Draw the scattering pattern of the points (x, y). Use the + symbol to represent points.

# %%
x = np.arange(1,10)
y = np.array([-0.57, -2.57, -4.80, -7.36, -8.78, -10.52, -12.85, -14.69, -16.78])

plt.scatter(x,y,marker="+")
plt.title("Task 6: Draw a dot pattern")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Task 7
#
# Read from CSV-file weight-height.csv to numpy-table information about the lengths and weights (in inches and pounds) of a group of students. Collect the lengths for the variable "length" and the weights for the variable "weight" by cutting the table.
#
# Convert lengths from inches to centimeters and weights from pounds to kilograms.
#
# Finally, calculate the means, medians, standard deviations, and variances of the lengths and weights.
#
# Extra: Draw a histogram of the lengths

# %%
dir = os.getcwd()
path = os.path.join(dir, "data/weight-height.csv")

data = np.genfromtxt(path, delimiter=',', skip_header=1)[:,1:]
length = data[:,0]
weight = data[:,1]

length_cm = length * 2.54
weight_kg = weight * 0.4535924

print("Mean:     {:6.2f}cm   {:6.2f}kg".format(np.mean(length_cm), np.mean(weight_kg)))
print("Median:   {:6.2f}cm   {:6.2f}kg".format(np.median(length_cm), np.median(weight_kg)))
print("Stdev:    {:6.2f}cm   {:6.2f}kg".format(np.std(length_cm),np.std(weight_kg)))
print("Var:      {:6.2f}cm   {:6.2f}kg".format(np.var(length_cm),np.var(weight_kg)))

plt.hist(length_cm,20)
plt.title("Histogram of lengths")
plt.ylabel("Freq")
plt.xlabel("Length cm")
plt.show()
# Out:
# Mean:     168.57cm    73.23kg
# Median:   168.45cm    73.12kg
# Stdev:      9.77cm    14.56kg
# Var:       95.50cm   212.09kg

# %% [markdown]
# ### Task 8
#
# Look for a command from the numpy documentation (or elsewhere on the Internet) to calculate the matrix determinant. The determinant is a number that does not require a deeper understanding here. Calculate the determinants of the matrices A, B and AB, where
# $$
# A=\begin{pmatrix}
# 1&2\\
# 3&4
# \end{pmatrix}{,} B=\begin{pmatrix}
# -1  & 1\\
# 5 & 7
# \end{pmatrix}
# $$
# and AB stands for matrix product. State that det (AB) = det (A) det (B) can be understood as the product of the numbers (the rounding error can be ignored).

# %%
A = np.array([1,2,3,4]).reshape(2,2)
B = np.array([-1,1,5,7]).reshape(2,2)

detA = np.linalg.det(A)
detB = np.linalg.det(B)
detAB = np.linalg.det(np.matmul(A,B))

print("det(A)  = {:.0f}".format(detA))
print("det(B)  = {:.0f}".format(detB))
print("det(AB) = {:.0f}".format(detAB))
# Out:
# det(A)  = -2
# det(B)  = -12
# det(AB) = 24

# %% [markdown]
# ### Task 9
#
# Calculate the inverse matrix of matrix A and  check with the matrix product that both $A A^{- 1}$ and $A^{- 1} A$ produce a unit matrix with ones in diagonals and zeros elsewhere (the values will not be exactly 1 and 0 due to floating point error).
# $$
# A=\begin{pmatrix}
# 1&2&3\\
# 0&1&4\\
# 5&6&0
# \end{pmatrix}
# $$

# %%
A = np.array([1,2,3,0,1,4,5,6,0]).reshape(3,3)
print(A)

Ainv = np.linalg.inv(A)
print(Ainv)

print( np.matmul(A, Ainv) ) 
print( np.matmul(Ainv, A))
# Out:
# [[1 2 3]
#  [0 1 4]
#  [5 6 0]]
# [[-24.  18.   5.]
#  [ 20. -15.  -4.]
#  [ -5.   4.   1.]]
# [[ 1.00000000e+00 -3.55271368e-15 -8.88178420e-16]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# [[ 1.00000000e+00 -7.10542736e-15  0.00000000e+00]
#  [ 0.00000000e+00  1.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -8.88178420e-16  1.00000000e+00]]
